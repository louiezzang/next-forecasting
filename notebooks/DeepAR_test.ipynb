# %% [markdown]
# <a href="https://colab.research.google.com/github/louiezzang/nextmining-forecasting/blob/main/notebooks/DeepAR_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/louiezzang/TimeSeries.git
# Out:
# Cloning into 'TimeSeries'...
# remote: Enumerating objects: 116, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 116 (delta 2), reused 5 (delta 2), pack-reused 107
# Receiving objects: 100% (116/116), 1.32 MiB | 9.78 MiB/s, done.
# Resolving deltas: 100% (50/50), done.

# %%
# %cd TimeSeries
# Out:
# /content/TimeSeries

# %%
# !python preprocess_elect.py
# Out:
# **** data_frame: (32304, 370)
# **** data_frame:                         MT_001      MT_002    MT_003  ...      MT_368       MT_369        MT_370
# 2011-01-01 00:00:00   0.000000    0.000000  0.000000  ...    0.000000     0.000000      0.000000
# 2011-01-01 01:00:00   0.000000    0.000000  0.000000  ...    0.000000     0.000000      0.000000
# 2011-01-01 02:00:00   0.000000    0.000000  0.000000  ...    0.000000     0.000000      0.000000
# 2011-01-01 03:00:00   0.000000    0.000000  0.000000  ...    0.000000     0.000000      0.000000
# 2011-01-01 04:00:00   0.000000    0.000000  0.000000  ...    0.000000     0.000000      0.000000
# ...                        ...         ...       ...  ...         ...          ...           ...
# 2014-09-07 19:00:00  36.802030  142.958748  7.819288  ...  208.681135  3036.656891  82108.108108
# 2014-09-07 20:00:00  13.959391  135.846373  6.950478  ...  215.358932  2973.607038  78486.486486
# ...

# %%
# !python train.py
# Out:
# [23:12:44] DeepAR.Train: Loading the datasets...
# [23:12:45] DeepAR.Data: train_len: 389101
# [23:12:45] DeepAR.Data: building datasets from data/elect...
# [23:12:45] DeepAR.Data: test_len: 2590
# [23:12:45] DeepAR.Data: building datasets from data/elect...
# [23:12:45] DeepAR.Data: weights: tensor([4.5579e-08, 4.7663e-08, 4.8446e-08,  ..., 8.4827e-05, 8.4776e-05,
#         8.4272e-05], dtype=torch.float64)
# [23:12:45] DeepAR.Data: num samples: 389101
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# [23:12:45] DeepAR.Train: Loading complete.
# ...
